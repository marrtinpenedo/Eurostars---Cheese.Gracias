# %%
import sys
sys.path.append("../src")
from data.loader import DataLoader
import pandas as pd

loader = DataLoader(data_dir="../data/raw")
c, h = loader.get_data()
print(c.head())
print(h.head())
# Out:
#      GUEST_ID COUNTRY_GUEST  GENDER_ID AGE_RANGE  LAST_2_YEARS_STAYS  \
# 0  1014907189            PT   Femenino     36-45                   2
# 1  1018922044            IT   Femenino     19-25                   1
# 2  1016865415            IT  Masculino     19-25                   1
# 3  1018327847            IT   Femenino     36-45                   1
# 4  1013580011            PT   Femenino     36-45                   2
#
#    CONFIRMED_RESERVATIONS  NUM_DISTINCT_HOTELS  CONFIRMED_RESERVATIONS_ADR  \
# 0                       2                    2                      109.24
# 1                       1                    1                      226.49
# 2                       1                    1                      310.45
# 3                       1                    1                      340.20
# 4                       2                    2                      169.16
#
#    AVG_LENGTH_STAY  AVG_BOOKING_LEADTIME  AVG_SCORE  RESERVATION_ID  \
# ...
